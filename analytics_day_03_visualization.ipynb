# %% [markdown]
# # PIVOT TABLE & formulas

# %% [markdown]
# * concatenation
#
# ![image.png](attachment:dab307c4-85d0-4191-9961-c7a6a047beb4.png)

# %% [markdown]
# * vlookup  - find the row with the string "Solutions" from the given table range B1:C5 and provide the info on the 2nd column based on exact match
#
# ![image.png](attachment:08a00813-f0c9-42da-b463-7284d7383ad6.png)

# %% [markdown]
# * LENGTH
#
# ![image.png](attachment:9dc165d9-f087-495c-a871-fe4f6a975f56.png)

# %% [markdown]
# * SUMIF - only those cells that meet the condition will be summed up
#
# ![image.png](attachment:1627ce4e-1b84-4041-98cc-55328db4f4ed.png)

# %% [markdown]
# * count days
#
# ![image.png](attachment:4c6ba04c-09c2-482a-9fe3-557f86c884e6.png)

# %% [markdown]
# * substitute
#
# ![image.png](attachment:cef9fa31-0b5b-47b7-8c29-4b4d74141bb9.png)

# %% [markdown]
# * min(if())  -  Then press Ctrl+Shift+Enter to array-enter the formula.
#
# ![image.png](attachment:bde943dc-2622-4839-9f84-315f5c5f8f61.png)

# %% [markdown]
# * countif()
#
# ![image.png](attachment:b4ca9d6d-4f01-4cea-9605-49bdc108b80f.png)

# %% [markdown]
# # load excel file and create pivot table
#
# ![image.png](attachment:4beedc83-fb8f-4f44-ba7f-e9d044286e43.png)
